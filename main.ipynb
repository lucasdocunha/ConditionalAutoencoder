# %%
import pandas as pd 
import numpy as np
import tensorflow as tf 
import os

# %%
import os
import tensorflow as tf

def listar_camadas(submodel):
    layers_info = []
    for layer in submodel.layers:
        info = {
            'nome': layer.name,
            'tipo': layer.__class__.__name__,
            'params_total': layer.count_params(),
            'params_treinaveis': sum(
                tf.keras.backend.count_params(w) for w in layer.trainable_weights
            ),
            'params_nao_treinaveis': sum(
                tf.keras.backend.count_params(w) for w in layer.non_trainable_weights
            ),
            'config': layer.get_config()
        }
        layers_info.append(info)
    return layers_info

import tensorflow as tf

def conv2d_info(layer):
    cfg = layer.get_config()
    return {
        'nome': layer.name,
        'filtros': cfg.get('filters'),
        'kernel': cfg.get('kernel_size'),
        'strides': cfg.get('strides'),
        'padding': cfg.get('padding'),
        'dilation_rate': cfg.get('dilation_rate'),
        'ativacao': cfg.get('activation'),
        'use_bias': cfg.get('use_bias'),
        'input_shape': layer.input.shape if layer.input is not None else None,
        'output_shape': layer.output.shape if layer.output is not None else None,
        'params_total': layer.count_params()
    }


for i in range(10):
    path = f'/home/lucas/ConditionalAutoencoder/Modelos/Modelo_Kyoto-{i}/Modelo-Base/Estrutura/Modelo_Kyoto-{i}.keras'
    print('\n' + '='*80)
    print(f'Modelo {i} -> {path}')
    print('='*80)

    if not os.path.exists(path):
        print('Arquivo não encontrado')
        continue

    try:
        model = tf.keras.models.load_model(path)
    except Exception as e:
        print('Erro ao carregar modelo:', e)
        continue

    for subname in ['encoder', 'decoder']:
        try:
            sub = model.get_layer(subname)
        except ValueError:
            continue

        print(f"\n=== Conv2D no {subname.upper()} ===")

        for layer in sub.layers:
            if isinstance(layer, tf.keras.layers.Conv2D):
                info = conv2d_info(layer)
                print(
                    f"\nLayer: {info['nome']}"
                    f"\n  filtros: {info['filtros']}"
                    f"\n  kernel: {info['kernel']}"
                    f"\n  strides: {info['strides']}"
                    f"\n  padding: {info['padding']}"
                    f"\n  dilation: {info['dilation_rate']}"
                    f"\n  ativacao: {info['ativacao']}"
                    f"\n  use_bias: {info['use_bias']}"
                    f"\n  input_shape: {info['input_shape']}"
                    f"\n  output_shape: {info['output_shape']}"
                    f"\n  params: {info['params_total']}"
                )
# Out:
# ================================================================================
# Modelo 0 -> /home/lucas/ConditionalAutoencoder/Modelos/Modelo_Kyoto-0/Modelo-Base/Estrutura/Modelo_Kyoto-0.keras
# ================================================================================
#
# === Conv2D no ENCODER ===
#
# Layer: conv2d
#   filtros: 8
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 64, 64, 3)
#   output_shape: (None, 64, 64, 8)
#   params: 224
#
# Layer: conv2d_1
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 8)
#   output_shape: (None, 32, 32, 16)
#   params: 1168
#
# === Conv2D no DECODER ===
#
# Layer: conv2d_2
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 16, 16, 16)
#   output_shape: (None, 16, 16, 16)
#   params: 2320
#
# Layer: conv2d_3
#   filtros: 8
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 16)
#   output_shape: (None, 32, 32, 8)
#   params: 1160
#
# Layer: conv2d_4
#   filtros: 3
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: sigmoid
#   use_bias: True
#   input_shape: (None, 64, 64, 8)
#   output_shape: (None, 64, 64, 3)
#   params: 219
#
# ================================================================================
# Modelo 1 -> /home/lucas/ConditionalAutoencoder/Modelos/Modelo_Kyoto-1/Modelo-Base/Estrutura/Modelo_Kyoto-1.keras
# ================================================================================
#
# === Conv2D no ENCODER ===
#
# Layer: conv2d
#   filtros: 32
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 64, 64, 3)
#   output_shape: (None, 64, 64, 32)
#   params: 896
#
# Layer: conv2d_1
#   filtros: 8
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 32)
#   output_shape: (None, 32, 32, 8)
#   params: 2312
#
# Layer: conv2d_2
#   filtros: 64
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 16, 16, 8)
#   output_shape: (None, 16, 16, 64)
#   params: 4672
#
# Layer: conv2d_3
#   filtros: 32
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 8, 8, 64)
#   output_shape: (None, 8, 8, 32)
#   params: 18464
#
# === Conv2D no DECODER ===
#
# Layer: conv2d_4
#   filtros: 32
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 8, 8, 32)
#   output_shape: (None, 8, 8, 32)
#   params: 9248
#
# Layer: conv2d_5
#   filtros: 64
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 8, 8, 32)
#   output_shape: (None, 8, 8, 64)
#   params: 18496
#
# Layer: conv2d_6
#   filtros: 8
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 16, 16, 64)
#   output_shape: (None, 16, 16, 8)
#   params: 4616
#
# Layer: conv2d_7
#   filtros: 32
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 8)
#   output_shape: (None, 32, 32, 32)
#   params: 2336
#
# Layer: conv2d_8
#   filtros: 3
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: sigmoid
#   use_bias: True
#   input_shape: (None, 64, 64, 32)
#   output_shape: (None, 64, 64, 3)
#   params: 867
#
# ================================================================================
# Modelo 2 -> /home/lucas/ConditionalAutoencoder/Modelos/Modelo_Kyoto-2/Modelo-Base/Estrutura/Modelo_Kyoto-2.keras
# ================================================================================
#
# === Conv2D no ENCODER ===
#
# Layer: conv2d
#   filtros: 32
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 64, 64, 3)
#   output_shape: (None, 64, 64, 32)
#   params: 896
#
# Layer: conv2d_1
#   filtros: 32
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 64, 64, 32)
#   output_shape: (None, 64, 64, 32)
#   params: 9248
#
# Layer: conv2d_2
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 64, 64, 32)
#   output_shape: (None, 64, 64, 16)
#   params: 4624
#
# Layer: conv2d_3
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 16)
#   output_shape: (None, 32, 32, 16)
#   params: 2320
#
# Layer: conv2d_4
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 16, 16, 16)
#   output_shape: (None, 16, 16, 16)
#   params: 2320
#
# === Conv2D no DECODER ===
#
# Layer: conv2d_5
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 8, 8, 16)
#   output_shape: (None, 8, 8, 16)
#   params: 2320
#
# Layer: conv2d_6
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 16, 16, 16)
#   output_shape: (None, 16, 16, 16)
#   params: 2320
#
# Layer: conv2d_7
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 16)
#   output_shape: (None, 32, 32, 16)
#   params: 2320
#
# Layer: conv2d_8
#   filtros: 32
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 64, 64, 16)
#   output_shape: (None, 64, 64, 32)
#   params: 4640
#
# Layer: conv2d_9
#   filtros: 32
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 64, 64, 32)
#   output_shape: (None, 64, 64, 32)
#   params: 9248
#
# Layer: conv2d_10
#   filtros: 3
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: sigmoid
#   use_bias: True
#   input_shape: (None, 64, 64, 32)
#   output_shape: (None, 64, 64, 3)
#   params: 867
#
# ================================================================================
# Modelo 3 -> /home/lucas/ConditionalAutoencoder/Modelos/Modelo_Kyoto-3/Modelo-Base/Estrutura/Modelo_Kyoto-3.keras
# ================================================================================
#
# === Conv2D no ENCODER ===
#
# Layer: conv2d
#   filtros: 32
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 64, 64, 3)
#   output_shape: (None, 64, 64, 32)
#   params: 896
#
# Layer: conv2d_1
#   filtros: 8
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 32)
#   output_shape: (None, 32, 32, 8)
#   params: 2312
#
# === Conv2D no DECODER ===
#
# Layer: conv2d_2
#   filtros: 8
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 16, 16, 8)
#   output_shape: (None, 16, 16, 8)
#   params: 584
#
# Layer: conv2d_3
#   filtros: 32
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 8)
#   output_shape: (None, 32, 32, 32)
#   params: 2336
#
# Layer: conv2d_4
#   filtros: 3
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: sigmoid
#   use_bias: True
#   input_shape: (None, 64, 64, 32)
#   output_shape: (None, 64, 64, 3)
#   params: 867
#
# ================================================================================
# Modelo 4 -> /home/lucas/ConditionalAutoencoder/Modelos/Modelo_Kyoto-4/Modelo-Base/Estrutura/Modelo_Kyoto-4.keras
# ================================================================================
#
# === Conv2D no ENCODER ===
#
# Layer: conv2d
#   filtros: 64
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 64, 64, 3)
#   output_shape: (None, 64, 64, 64)
#   params: 1792
#
# Layer: conv2d_1
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 64)
#   output_shape: (None, 32, 32, 16)
#   params: 9232
#
# Layer: conv2d_2
#   filtros: 64
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 16)
#   output_shape: (None, 32, 32, 64)
#   params: 9280
#
# Layer: conv2d_3
#   filtros: 128
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 16, 16, 64)
#   output_shape: (None, 16, 16, 128)
#   params: 73856
#
# Layer: conv2d_4
#   filtros: 64
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 8, 8, 128)
#   output_shape: (None, 8, 8, 64)
#   params: 73792
#
# Layer: conv2d_5
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 4, 4, 64)
#   output_shape: (None, 4, 4, 16)
#   params: 9232
#
# === Conv2D no DECODER ===
#
# Layer: conv2d_6
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 2, 2, 16)
#   output_shape: (None, 2, 2, 16)
#   params: 2320
#
# Layer: conv2d_7
#   filtros: 64
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 4, 4, 16)
#   output_shape: (None, 4, 4, 64)
#   params: 9280
#
# Layer: conv2d_8
#   filtros: 128
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 8, 8, 64)
#   output_shape: (None, 8, 8, 128)
#   params: 73856
#
# Layer: conv2d_9
#   filtros: 64
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 16, 16, 128)
#   output_shape: (None, 16, 16, 64)
#   params: 73792
#
# Layer: conv2d_10
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 64)
#   output_shape: (None, 32, 32, 16)
#   params: 9232
#
# Layer: conv2d_11
#   filtros: 64
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 16)
#   output_shape: (None, 32, 32, 64)
#   params: 9280
#
# Layer: conv2d_12
#   filtros: 3
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: sigmoid
#   use_bias: True
#   input_shape: (None, 64, 64, 64)
#   output_shape: (None, 64, 64, 3)
#   params: 1731
#
# ================================================================================
# Modelo 5 -> /home/lucas/ConditionalAutoencoder/Modelos/Modelo_Kyoto-5/Modelo-Base/Estrutura/Modelo_Kyoto-5.keras
# ================================================================================
#
# === Conv2D no ENCODER ===
#
# Layer: conv2d
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 64, 64, 3)
#   output_shape: (None, 64, 64, 16)
#   params: 448
#
# Layer: conv2d_1
#   filtros: 128
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 16)
#   output_shape: (None, 32, 32, 128)
#   params: 18560
#
# Layer: conv2d_2
#   filtros: 8
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 16, 16, 128)
#   output_shape: (None, 16, 16, 8)
#   params: 9224
#
# === Conv2D no DECODER ===
#
# Layer: conv2d_3
#   filtros: 8
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 8, 8, 8)
#   output_shape: (None, 8, 8, 8)
#   params: 584
#
# Layer: conv2d_4
#   filtros: 128
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 16, 16, 8)
#   output_shape: (None, 16, 16, 128)
#   params: 9344
#
# Layer: conv2d_5
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 128)
#   output_shape: (None, 32, 32, 16)
#   params: 18448
#
# Layer: conv2d_6
#   filtros: 3
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: sigmoid
#   use_bias: True
#   input_shape: (None, 64, 64, 16)
#   output_shape: (None, 64, 64, 3)
#   params: 435
#
# ================================================================================
# Modelo 6 -> /home/lucas/ConditionalAutoencoder/Modelos/Modelo_Kyoto-6/Modelo-Base/Estrutura/Modelo_Kyoto-6.keras
# ================================================================================
#
# === Conv2D no ENCODER ===
#
# Layer: conv2d
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 64, 64, 3)
#   output_shape: (None, 64, 64, 16)
#   params: 448
#
# Layer: conv2d_1
#   filtros: 64
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 16)
#   output_shape: (None, 32, 32, 64)
#   params: 9280
#
# === Conv2D no DECODER ===
#
# Layer: conv2d_2
#   filtros: 64
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 16, 16, 64)
#   output_shape: (None, 16, 16, 64)
#   params: 36928
#
# Layer: conv2d_3
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 64)
#   output_shape: (None, 32, 32, 16)
#   params: 9232
#
# Layer: conv2d_4
#   filtros: 3
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: sigmoid
#   use_bias: True
#   input_shape: (None, 64, 64, 16)
#   output_shape: (None, 64, 64, 3)
#   params: 435
#
# ================================================================================
# Modelo 7 -> /home/lucas/ConditionalAutoencoder/Modelos/Modelo_Kyoto-7/Modelo-Base/Estrutura/Modelo_Kyoto-7.keras
# ================================================================================
#
# === Conv2D no ENCODER ===
#
# Layer: conv2d
#   filtros: 128
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 64, 64, 3)
#   output_shape: (None, 64, 64, 128)
#   params: 3584
#
# Layer: conv2d_1
#   filtros: 32
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 64, 64, 128)
#   output_shape: (None, 64, 64, 32)
#   params: 36896
#
# Layer: conv2d_2
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 64, 64, 32)
#   output_shape: (None, 64, 64, 16)
#   params: 4624
#
# === Conv2D no DECODER ===
#
# Layer: conv2d_3
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 16)
#   output_shape: (None, 32, 32, 16)
#   params: 2320
#
# Layer: conv2d_4
#   filtros: 32
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 64, 64, 16)
#   output_shape: (None, 64, 64, 32)
#   params: 4640
#
# Layer: conv2d_5
#   filtros: 128
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 64, 64, 32)
#   output_shape: (None, 64, 64, 128)
#   params: 36992
#
# Layer: conv2d_6
#   filtros: 3
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: sigmoid
#   use_bias: True
#   input_shape: (None, 64, 64, 128)
#   output_shape: (None, 64, 64, 3)
#   params: 3459
#
# ================================================================================
# Modelo 8 -> /home/lucas/ConditionalAutoencoder/Modelos/Modelo_Kyoto-8/Modelo-Base/Estrutura/Modelo_Kyoto-8.keras
# ================================================================================
#
# === Conv2D no ENCODER ===
#
# Layer: conv2d
#   filtros: 64
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 64, 64, 3)
#   output_shape: (None, 64, 64, 64)
#   params: 1792
#
# Layer: conv2d_1
#   filtros: 128
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 64)
#   output_shape: (None, 32, 32, 128)
#   params: 73856
#
# === Conv2D no DECODER ===
#
# Layer: conv2d_2
#   filtros: 128
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 16, 16, 128)
#   output_shape: (None, 16, 16, 128)
#   params: 147584
#
# Layer: conv2d_3
#   filtros: 64
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 128)
#   output_shape: (None, 32, 32, 64)
#   params: 73792
#
# Layer: conv2d_4
#   filtros: 3
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: sigmoid
#   use_bias: True
#   input_shape: (None, 64, 64, 64)
#   output_shape: (None, 64, 64, 3)
#   params: 1731
#
# ================================================================================
# Modelo 9 -> /home/lucas/ConditionalAutoencoder/Modelos/Modelo_Kyoto-9/Modelo-Base/Estrutura/Modelo_Kyoto-9.keras
# ================================================================================
#
# === Conv2D no ENCODER ===
#
# Layer: conv2d
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 64, 64, 3)
#   output_shape: (None, 64, 64, 16)
#   params: 448
#
# Layer: conv2d_1
#   filtros: 8
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 16)
#   output_shape: (None, 32, 32, 8)
#   params: 1160
#
# Layer: conv2d_2
#   filtros: 32
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 16, 16, 8)
#   output_shape: (None, 16, 16, 32)
#   params: 2336
#
# Layer: conv2d_3
#   filtros: 32
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 8, 8, 32)
#   output_shape: (None, 8, 8, 32)
#   params: 9248
#
# Layer: conv2d_4
#   filtros: 32
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 4, 4, 32)
#   output_shape: (None, 4, 4, 32)
#   params: 9248
#
# === Conv2D no DECODER ===
#
# Layer: conv2d_5
#   filtros: 32
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 2, 2, 32)
#   output_shape: (None, 2, 2, 32)
#   params: 9248
#
# Layer: conv2d_6
#   filtros: 32
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 4, 4, 32)
#   output_shape: (None, 4, 4, 32)
#   params: 9248
#
# Layer: conv2d_7
#   filtros: 32
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 8, 8, 32)
#   output_shape: (None, 8, 8, 32)
#   params: 9248
#
# Layer: conv2d_8
#   filtros: 8
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 16, 16, 32)
#   output_shape: (None, 16, 16, 8)
#   params: 2312
#
# Layer: conv2d_9
#   filtros: 16
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: relu
#   use_bias: True
#   input_shape: (None, 32, 32, 8)
#   output_shape: (None, 32, 32, 16)
#   params: 1168
#
# Layer: conv2d_10
#   filtros: 3
#   kernel: (3, 3)
#   strides: (1, 1)
#   padding: same
#   dilation: (1, 1)
#   ativacao: sigmoid
#   use_bias: True
#   input_shape: (None, 64, 64, 16)
#   output_shape: (None, 64, 64, 3)
#   params: 435
